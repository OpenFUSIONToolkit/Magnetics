# %% [markdown]
# # 3D magnetics spatial fit — DIII-D (configurable shot)
#
# A worked example of the **SLCONTOUR-style quasi-stationary spatial fit** (VISION.md §4.1),
# run **locally** — off MDSplus — with the `magnetics.core.qs_*` pipeline. It reads the per-shot
# signals from `data/datafile/shot_<shot>.h5` and the device geometry from `data/device/diiid.json`.
#
# **Pipeline:** `load → prep → fit → plot`:
#
# | module | role |
# |---|---|
# | `qs_io_data.load_shot` | read `shot_<n>.h5` signals + join the device-JSON geometry (derived `*_end1/2` ends) |
# | `qs_prep.prepare` | trim, integrate, causal band-pass, detrend, SVD-condition |
# | `qs_fit.fit` | build the basis matrix + SVD-conditioned least-squares modal fit |
# | `qs_run.run_steps` | the load → prep → fit orchestrator |
# | `qs_plots.*` | sensor map, signals, SVD diagnostics, fit quality, mode amp/phase, φ-vs-time contour |
#
# (The production/GUI path adapts the same `qs_fit` Dataset through `qs_bridge`; `qs_plots` here is
# the standalone-matplotlib view.)
#
# The run is driven entirely by the **Parameters** cell below — change `SHOT`, `CHANNEL_FILTER`,
# `TIME_TRIM`, or the mode lists to analyse a different shot or array.  The default analyses the
# LFS-midplane toroidal Bp array (`Bp_LFS_midplane`) of shot **199749** for toroidal mode numbers
# n = 1, 2, 3.

# %%
import numpy as np
import matplotlib.pyplot as plt

from magnetics.core.qs_io_data import load_shot, valid_channels, available_subsets
from magnetics.core.qs_device import resolve_channel_filter
from magnetics.core.qs_run import run_steps
from magnetics.core import qs_plots as plots

# %matplotlib inline

# %% [markdown]
# ## Run parameters
#
# Everything below is driven by these names — this is the only cell to edit to analyse a different
# shot or sensor array.

# %%
# ── Run parameters — change these to analyse a different shot/array ──
SHOT = 199749  # data/datafile/shot_<SHOT>.h5
CHANNEL_FILTER = "Bp_HFS_Sensors"  # friendly name (see available_subsets) or a regex
TIME_TRIM = (3.2, 3.48)  # seconds; must lie inside the shot file's window
NS, MS = (1, 2, 3), (0,)  # toroidal / poloidal mode numbers

# detrend: 'none' | 'baseline' | 'linear' | 'endpoints'.  DETREND_BAND is the
# sub-window used to estimate the trend — here the first 0.01 s of TIME_TRIM.
DETREND_TYPE = "baseline"
DETREND_BAND = (3.23, 3.25)

PREP_KWARGS = dict(
    cutoff_hz=(5, 1000), energy=1.0, detrend_type=DETREND_TYPE, detrend_band=DETREND_BAND
)

# %% [markdown]
# ## 1. Load the shot
#
# `load_shot` reads the raw sensor signals from `data/datafile/shot_<SHOT>.h5` and joins the
# per-channel geometry — including the derived sensor-end coordinates (`*_end1/2`) — from
# `data/device/diiid.json`.  All sensor channels are interpolated onto a single common time axis
# (in seconds); the global `ip`/`bt` traces become the `plasma` Dataset.  The new files carry no
# DC-coupling matrix, so `coupling` is `None`.

# %%
sd = load_shot(SHOT)
print(f"shot {sd.shot}  device {sd.device}")
print("RAW channels:", sd.raw.sizes["channel"], " time samples:", sd.raw.sizes["time"])
print(f"file window: {float(sd.raw.time[0]):.4f}–{float(sd.raw.time[-1]):.4f} s")
print("helicity:", sd.plasma.attrs["helicity"])

# channels in the selected array that carry good data
good = valid_channels(sd.raw, CHANNEL_FILTER, sd.device)
print(f"\n{CHANNEL_FILTER}: {len(good)} valid sensors  -> resolves |n| <= {(len(good) - 1) // 2}")
print(good)

# the plot helpers match channel names with re.match, so turn the friendly
# filter into an explicit regex of its sensor names
ARRAY_REGEX = "|".join(resolve_channel_filter(CHANNEL_FILTER, sd.device))
# Out:
# Channel 'kappa' has no geometry in DIII-D device file -> skipping
# shot 199749  device DIII-D
# RAW channels: 155  time samples: 799993
# file window: 1.0000–5.0000 s
# helicity: -1
#
# Bp_HFS_Sensors: 19 valid sensors  -> resolves |n| <= 9
# [np.str_('MPID1A049'), np.str_('MPID1A109'), np.str_('MPID1A139'), np.str_('MPID1A199'), np.str_('MPID1A244'), np.str_('MPID1B049'), np.str_('MPID1B109'), np.str_('MPID1B139'), np.str_('MPID1B199'), np.str_('MPID1B244'), np.str_('MPID1B274'), np.str_('MPID2A199'), np.str_('MPID2B199'), np.str_('MPID3A199'), np.str_('MPID3B199'), np.str_('MPID4A199'), np.str_('MPID4B199'), np.str_('MPID5A199'), np.str_('MPID5B199')]

# %% [markdown]
# ### Named sensor / coil subsets
#
# Any of these names can be passed as `CHANNEL_FILTER` (they come from the `sensor_sets` in
# `data/device/diiid.json`; names work with spaces or underscores).

# %%
for name, sensors in available_subsets(sd.device).items():
    print(f"{name:24s} {sensors}")
# Out:
# Bp LFS midplane          ['MPID66M020', 'MPID66M067', 'MPID66M097', 'MPID66M127', 'MPID66M157', 'MPID66M200', 'MPID66M247', 'MPID66M277', 'MPID66M307', 'MPID66M340']
# Bp LFS midplane bdot     ['MPI66M020D', 'MPI66M067D', 'MPI66M097D', 'MPI66M127D', 'MPI66M132D', 'MPI66M137D', 'MPI66M157D', 'MPI66M200D', 'MPI66M247D', 'MPI66M277D', 'MPI66M307D', 'MPI66M312D', 'MPI66M322D', 'MPI66M340D']
# Bp LFS R+1               ['MPID67A022', 'MPID67A037', 'MPID67A052', 'MPID67A097', 'MPID67A157', 'MPID67A217', 'MPID67A277', 'MPID67A337']
# Bp LFS R+2               ['MPID79A072', 'MPID79A147', 'MPID79A222', 'MPID79A272']
# Bp LFS R-1               ['MPID67B022', 'MPID67B037', 'MPID67B052', 'MPID67B097', 'MPID67B157', 'MPID67B217', 'MPID67B277', 'MPID67B337']
# Bp LFS R-2               ['MPID79B067', 'MPID79B142', 'MPID79B217', 'MPID79B277']
# Bp LFS Sensors           ['MPID66M020', 'MPID66M067', 'MPID66M097', 'MPID66M127', 'MPID66M157', 'MPID66M200', 'MPID66M247', 'MPID66M277', 'MPID66M307', 'MPID66M340', 'MPID67A022', 'MPID67A037', 'MPID67A052', 'MPID67A097', 'MPID67A157', 'MPID67A217', 'MPID67A277', 'MPID67A337', 'MPID67B022', 'MPID67B037', 'MPID67B052', 'MPID67B097', 'MPID67B157', 'MPID67B217', 'MPID67B277', 'MPID67B337', 'MPID79A072', 'MPID79A147', 'MPID79A222', 'MPID79A272', 'MPID79B067', 'MPID79B142', 'MPID79B217', 'MPID79B277']
# Bp HFS +midplane         ['MPID1A199', 'MPID1A011', 'MPID1A049', 'MPID1A109', 'MPID1A139', 'MPID1A244', 'MPID1A274', 'MPID1A341']
# Bp HFS -midplane         ['MPID1B011', 'MPID1B049', 'MPID1B109', 'MPID1B139', 'MPID1B199', 'MPID1B244', 'MPID1B274', 'MPID1B341']
# Bp HFS Sensors           ['MPID5A199', 'MPID4A199', 'MPID3A199', 'MPID2A199', 'MPID1A199', 'MPID2B199', 'MPID3B199', 'MPID4B199', 'MPID5B199', 'MPID1A011', 'MPID1A049', 'MPID1A109', 'MPID1A139', 'MPID1A244', 'MPID1A274', 'MPID1A341', 'MPID1B011', 'MPID1B049', 'MPID1B109', 'MPID1B139', 'MPID1B199', 'MPID1B244', 'MPID1B274', 'MPID1B341']
# Bp All                   ['MPID66M020', 'MPID66M067', 'MPID66M097', 'MPID66M127', 'MPID66M157', 'MPID66M200', 'MPID66M247', 'MPID66M277', 'MPID66M307', 'MPID66M340', 'MPID67A022', 'MPID67A037', 'MPID67A052', 'MPID67A097', 'MPID67A157', 'MPID67A217', 'MPID67A277', 'MPID67A337', 'MPID67B022', 'MPID67B037', 'MPID67B052', 'MPID67B097', 'MPID67B157', 'MPID67B217', 'MPID67B277', 'MPID67B337', 'MPID79A072', 'MPID79A147', 'MPID79A222', 'MPID79A272', 'MPID79B067', 'MPID79B142', 'MPID79B217', 'MPID79B277', 'MPID5A199', 'MPID4A199', 'MPID3A199', 'MPID2A199', 'MPID1A199', 'MPID2B199', 'MPID3B199', 'MPID4B199', 'MPID5B199', 'MPID1A011', 'MPID1A049', 'MPID1A109', 'MPID1A139', 'MPID1A244', 'MPID1A274', 'MPID1A341', 'MPID1B011', 'MPID1B049', 'MPID1B109', 'MPID1B139', 'MPID1B199', 'MPID1B244', 'MPID1B274', 'MPID1B341']
# Br LFS midplane          ['ISLD66M017', 'ISLD66M042', 'ISLD66M072', 'ISLD66M102', 'ISLD66M132', 'ISLD66M197', 'ISLD66M252', 'ISLD66M312']
# Br LFS R+1               ['ISLD67A017', 'ISLD67A052', 'ISLD67A072', 'ISLD67A112', 'ISLD67A132', 'ISLD67A197', 'ISLD67A252', 'ISLD67A312']
# Br LFS R+2               ['ISLD79A072', 'ISLD79A147', 'ISLD79A222', 'ISLD79A272']
# Br LFS R-1               ['ISLD67B017', 'ISLD67B052', 'ISLD67B072', 'ISLD67B112', 'ISLD67B132', 'ISLD67B197', 'ISLD67B252', 'ISLD67B312']
# Br LFS R-2               ['ISLD79B067', 'ISLD79B142', 'ISLD79B217', 'ISLD79B277']
# Br LFS Sensors           ['ISLD66M017', 'ISLD66M042', 'ISLD66M072', 'ISLD66M102', 'ISLD66M132', 'ISLD66M197', 'ISLD66M252', 'ISLD66M312', 'ISLD67A017', 'ISLD67A052', 'ISLD67A072', 'ISLD67A112', 'ISLD67A132', 'ISLD67A197', 'ISLD67A252', 'ISLD67A312', 'ISLD67B017', 'ISLD67B052', 'ISLD67B072', 'ISLD67B112', 'ISLD67B132', 'ISLD67B197', 'ISLD67B252', 'ISLD67B312', 'ISLD79A072', 'ISLD79A147', 'ISLD79A222', 'ISLD79A272', 'ISLD79B067', 'ISLD79B142', 'ISLD79B217', 'ISLD79B277']
# Br HFS +midplane         ['ISLD1A011', 'ISLD1A049', 'ISLD1A109', 'ISLD1A139', 'ISLD1A199', 'ISLD1A244', 'ISLD1A274', 'ISLD1A341']
# Br HFS -midplane         ['ISLD1B011', 'ISLD1B049', 'ISLD1B109', 'ISLD1B139', 'ISLD1B199', 'ISLD1B244', 'ISLD1B274', 'ISLD1B341']
# Br HFS Sensors           ['ISLD5A199', 'ISLD4A199', 'ISLD3A199', 'ISLD2A199', 'ISLD2B199', 'ISLD3B199', 'ISLD4B199', 'ISLD5B199', 'ISLD1A011', 'ISLD1A049', 'ISLD1A109', 'ISLD1A139', 'ISLD1A199', 'ISLD1A244', 'ISLD1A274', 'ISLD1A341', 'ISLD1B011', 'ISLD1B049', 'ISLD1B109', 'ISLD1B139', 'ISLD1B199', 'ISLD1B244', 'ISLD1B274', 'ISLD1B341']
# Bp and Bp Dot All        ['MPID66M020', 'MPID66M067', 'MPID66M097', 'MPID66M127', 'MPID66M157', 'MPID66M200', 'MPID66M247', 'MPID66M277', 'MPID66M307', 'MPID66M340', 'MPID67A022', 'MPID67A037', 'MPID67A052', 'MPID67A097', 'MPID67A157', 'MPID67A217', 'MPID67A277', 'MPID67A337', 'MPID67B022', 'MPID67B037', 'MPID67B052', 'MPID67B097', 'MPID67B157', 'MPID67B217', 'MPID67B277', 'MPID67B337', 'MPID79A072', 'MPID79A147', 'MPID79A222', 'MPID79A272', 'MPID79B067', 'MPID79B142', 'MPID79B217', 'MPID79B277', 'MPID5A199', 'MPID4A199', 'MPID3A199', 'MPID2A199', 'MPID1A199', 'MPID2B199', 'MPID3B199', 'MPID4B199', 'MPID5B199', 'MPID1A011', 'MPID1A049', 'MPID1A109', 'MPID1A139', 'MPID1A244', 'MPID1A274', 'MPID1A341', 'MPID1B011', 'MPID1B049', 'MPID1B109', 'MPID1B139', 'MPID1B199', 'MPID1B244', 'MPID1B274', 'MPID1B341', 'MPI66M020D', 'MPI66M067D', 'MPI66M097D', 'MPI66M127D', 'MPI66M132D', 'MPI66M137D', 'MPI66M157D', 'MPI66M200D', 'MPI66M247D', 'MPI66M277D', 'MPI66M307D', 'MPI66M312D', 'MPI66M322D', 'MPI66M340D']
# Br All                   ['ISLD66M017', 'ISLD66M042', 'ISLD66M072', 'ISLD66M102', 'ISLD66M132', 'ISLD66M197', 'ISLD66M252', 'ISLD66M312', 'ISLD67A017', 'ISLD67A052', 'ISLD67A072', 'ISLD67A112', 'ISLD67A132', 'ISLD67A197', 'ISLD67A252', 'ISLD67A312', 'ISLD67B017', 'ISLD67B052', 'ISLD67B072', 'ISLD67B112', 'ISLD67B132', 'ISLD67B197', 'ISLD67B252', 'ISLD67B312', 'ISLD79A072', 'ISLD79A147', 'ISLD79A222', 'ISLD79A272', 'ISLD79B067', 'ISLD79B142', 'ISLD79B217', 'ISLD79B277', 'ISLD5A199', 'ISLD4A199', 'ISLD3A199', 'ISLD2A199', 'ISLD2B199', 'ISLD3B199', 'ISLD4B199', 'ISLD5B199', 'ISLD1A011', 'ISLD1A049', 'ISLD1A109', 'ISLD1A139', 'ISLD1A199', 'ISLD1A244', 'ISLD1A274', 'ISLD1A341', 'ISLD1B011', 'ISLD1B049', 'ISLD1B109', 'ISLD1B139', 'ISLD1B199', 'ISLD1B244', 'ISLD1B274', 'ISLD1B341']
# Upper I-coils            ['IU30', 'IU90', 'IU150', 'IU210', 'IU270', 'IU330']
# Lower I-coils            ['IL30', 'IL90', 'IL150', 'IL210', 'IL270', 'IL330']
# C-coils                  ['C19', 'C79', 'C139', 'C199', 'C259', 'C319']
# All 3D Coils             ['C19', 'C79', 'C139', 'C199', 'C259', 'C319', 'IL30', 'IL90', 'IL150', 'IL210', 'IL270', 'IL330', 'IU30', 'IU90', 'IU150', 'IU210', 'IU270', 'IU330']
# All LFS Bp Arrays        ['MPID79B067', 'MPID79B142', 'MPID79B217', 'MPID79B277', 'MPID67B022', 'MPID67B037', 'MPID67B052', 'MPID67B097', 'MPID67B157', 'MPID67B217', 'MPID67B277', 'MPID67B337', 'MPID66M020', 'MPID66M067', 'MPID66M097', 'MPID66M127', 'MPID66M157', 'MPID66M200', 'MPID66M247', 'MPID66M277', 'MPID66M307', 'MPID66M340', 'MPID67A022', 'MPID67A037', 'MPID67A052', 'MPID67A097', 'MPID67A157', 'MPID67A217', 'MPID67A277', 'MPID67A337', 'MPID79A072', 'MPID79A147', 'MPID79A222', 'MPID79A272']
# All LFS Br Arrays        ['ISLD79B067', 'ISLD79B142', 'ISLD79B217', 'ISLD79B277', 'ISLD67B017', 'ISLD67B052', 'ISLD67B072', 'ISLD67B112', 'ISLD67B132', 'ISLD67B197', 'ISLD67B252', 'ISLD67B312', 'ISLD66M017', 'ISLD66M042', 'ISLD66M072', 'ISLD66M102', 'ISLD66M132', 'ISLD66M197', 'ISLD66M252', 'ISLD66M312', 'ISLD67A017', 'ISLD67A052', 'ISLD67A072', 'ISLD67A112', 'ISLD67A132', 'ISLD67A197', 'ISLD67A252', 'ISLD67A312', 'ISLD79A072', 'ISLD79A147', 'ISLD79A222', 'ISLD79A272']

# %% [markdown]
# ## 2. Sensor geometry
#
# The toroidal array sits at the LFS midplane (`theta ≈ 0`), spread around the torus in `phi`.

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
plots.plot_sensors(sd.raw, ARRAY_REGEX, geometry="rz", ax=ax[0])
ax[0].set_title("Cross-section (R–z)")
plots.plot_sensors(sd.raw, ARRAY_REGEX, geometry="cylindrical", ax=ax[1])
ax[1].set_title("Unrolled (phi–theta)")
plt.tight_layout()

# %% [markdown]
# ### Where the named sensor sets sit
#
# Overlay several named Bp sensor sets from `diiid.json`, each set in its own colour. The unrolled
# (phi, theta) panel shows the arrays as bands at distinct poloidal angles (midplane, R±1, R±2,
# HFS); the R–z panel shows their radial placement against the wall. (Sets whose sensors aren't in
# this shot simply don't draw.)

# %%
sets = ["Bp_LFS_midplane", "Bp_LFS_R+1", "Bp_LFS_R-1", "Bp_LFS_R+2", "Bp_LFS_R-2", "Bp_HFS_Sensors"]
colors = plt.cm.tab10.colors

fig, ax = plt.subplots(1, 2, figsize=(13, 5))
handles = []
for i, name in enumerate(sets):
    regex = "|".join(
        resolve_channel_filter(name, sd.device)
    )  # friendly name -> regex of its sensors
    plots.plot_sensors(sd.raw, regex, geometry="cylindrical", ax=ax[0], color=colors[i])
    plots.plot_sensors(sd.raw, regex, geometry="rz", ax=ax[1], color=colors[i])
    handles.append(plt.Line2D([], [], color=colors[i], label=name))

ax[0].set_title("Unrolled (phi–theta)")
ax[1].set_title("Cross-section (R–z)")
ax[0].legend(handles=handles, fontsize=8, loc="upper right")
plt.tight_layout()

# %% [markdown]
# ## 3. Prep + fit
#
# `run_steps` trims to the `TIME_TRIM` window (3.3–3.5 s for shot 199749), causal band-passes
# 5–250 Hz, SVD-conditions the data matrix (keeping 98% of the energy), removes a `DETREND_TYPE`
# baseline estimated from the first 0.01 s of the window, and fits the n = 1, 2, 3 toroidal
# harmonics. The reported **condition number K** is the central trust metric (warn K > 10, error
# K > 20).

# %%
r = run_steps(
    SHOT,
    channel_filter=CHANNEL_FILTER,
    ns=NS,
    ms=MS,
    time_trim=TIME_TRIM,
    prep_kwargs=PREP_KWARGS,
)
print(f"\ncondition number K = {r.condition_number:.2f}")
print(f"mean reduced chi^2 = {float(np.nanmean(r.fit['red_chi_sq'].values)):.1f}")
print(
    f"data-matrix SVD effective rank (98% energy) = {r.fit.attrs['signal_effective_rank']} "
    f"of {r.fit.sizes['channel']} sensors"
)
# Out:
# Channel 'kappa' has no geometry in DIII-D device file -> skipping
# condition number K = 9.14
# mean reduced chi^2 = 26.9
# data-matrix SVD effective rank (98% energy) = 19 of 19 sensors

# %% [markdown]
# ## 4. Signal conditioning
#
# PREPARED traces (band-passed, SVD-cleaned) over the faint shifted RAW traces.

# %%
plots.plot_signal(r.raw, r.prepared, ARRAY_REGEX)
plt.gcf().set_size_inches(9, 4)

# %% [markdown]
# ## 5. SVD conditioning (VISION's ≈ 98% energy)
#
# **Top:** cumulative energy of the data-matrix singular values — a handful of coherent spatial
# structures capture nearly all the energy (the rotating mode + its harmonics), the rest is noise.
# **Bottom:** the design-matrix condition number per singular value, against the `fit_cond` cutoff.

# %%
plots.plot_svds(r.fit)
# Out:
# array([<Axes: title={'center': 'Data Matrix Conditioning'}, xlabel='Cumulative Singular Value Index', ylabel='Energy Fraction'>,
#        <Axes: title={'center': 'Design Matrix Conditioning'}, xlabel='Singular Value Index', ylabel='Condition Number'>],
#       dtype=object)

# %% [markdown]
# ## 6. Fit quality
#
# Reduced chi^2, the signals, and the worst residuals. (chi^2 sits above 1 here because the
# constant 2e-5 T sensor sigma is optimistic relative to unmodeled higher-n structure — the residuals
# are still small compared with the signals.)

# %%
plots.plot_fit(r.fit)
# Out:
# array([<Axes: title={'center': '199749'}, xlabel='time', ylabel='Reduced $\\chi^2$'>,
#        <Axes: xlabel='time', ylabel='Signal'>,
#        <Axes: xlabel='time (s)', ylabel='Residual'>], dtype=object)

# %% [markdown]
# ## 7. Mode amplitude & phase vs time
#
# Amplitude and phase of each fitted (n, m) mode through the window. A **rotating** mode shows a
# phase that winds steadily in time; as a mode **slows and locks** its phase flattens and its
# amplitude typically grows. (For VISION's reference shot 154551 the n = 1 does exactly this —
# rotating early, then slowing and locking.)

# %%
plots.plot_fit_modes(r.fit)
# Out:
# array([<Axes: title={'center': '199749'}, ylabel='Amplitude'>,
#        <Axes: xlabel='Time (s)', ylabel='Phase (deg)'>], dtype=object)

# %% [markdown]
# ## 8. The SLCONTOUR phi-vs-time contour
#
# Reconstruct the fitted dB on a (toroidal angle) × time grid. A rotating mode shows **diagonal
# stripes**; a mode that slows and locks straightens those stripes into vertical bands. White
# markers trace the instantaneous peak (the mode's toroidal phase); the top panel is the RMS
# amplitude.

# %%
# fix_value is the poloidal angle of the slice; the LFS-midplane array sits at theta ~ 0
plots.plot_slice(r.fit, fix_coord="theta", fix_value=0.0)
# Out:
# <Axes: xlabel='Time (s)', ylabel='Toroidal Angle (deg.)'>

# %% [markdown]
# ---
# ### Recap
#
# We reproduced the VISION §4.1 SLCONTOUR outputs locally with the `magnetics.core.qs_*` pipeline,
# driven off the `data/datafile/shot_<SHOT>.h5` signals and `data/device/diiid.json` geometry: sensor
# map, conditioned signals, data/design-matrix SVD diagnostics, fit quality, **amplitude & phase of
# each (n, m) mode vs time**, and the **phi-vs-time contour**. To analyse a different shot or array,
# edit the **Parameters** cell (`SHOT`, `CHANNEL_FILTER`, `TIME_TRIM`, `NS`/`MS`).
